# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Roberto Gil**</BR>
# I'd like to be a Data Scientst

# %% [markdown]
# *I am interested in data science because i believe that with the low prices on sensors new raw data will be available to that can have the answer to improve our day to day life.*

# %% [markdown]
# ###  The following code give the result of multiplying four times five and print out the result

# %%
four=4
five=5
result=4*5
print(result)
# Out:
# 20

# %% [markdown]
# horizontal rule:
# ***

# %% [markdown]
# bulleted list:
# - one
# - two
# - three

# %% [markdown]
# numbered list:
# 1. one
# 2. two
# 3. three

# %% [markdown]
#  tables:
# |Head1|Head2|Head3|
# |-----|-----|-----|
# |R1C1 |R1C2 |R1C3 |
# |R2C1 |R2C2 |R2C3 |

# %% [markdown]
# https://commons.wikimedia.org/wiki/File:IBM_logo.svg

# %% [markdown]
# ![](https://upload.wikimedia.org/wikipedia/commons/5/51/IBM_logo.svg)

# %% [markdown]
# code/syntax highlighting
# ```python
# s = "Python syntax highlighting"
# print s
# ```

# %% [markdown]
# >blocked quotes
# >>Nested Block quotes

# %% [markdown]
# ~~strikethrough.~~
